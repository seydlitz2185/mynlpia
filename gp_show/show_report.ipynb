# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
report = pd.read_csv('report_final.csv')
report.head()
model = report.model
acc = report.accuracy
precision = report.precision_1
recall = report.recall_1
f1 = report.f1_1
